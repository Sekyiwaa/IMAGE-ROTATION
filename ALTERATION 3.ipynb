# %%
from PIL import Image
import numpy as np
img = Image.open("PROJECT PURPLE.jpg")
img 

x = np.array(img)
Image.fromarray(np.rot90(img))
# Out:
# <PIL.Image.Image image mode=RGB size=275x183 at 0x7F4CD82536D0>

# %%
def round(x):
    return int(floor(x)+1*((x-floor(x))>=0.5))

# %%
height,width = img.size
print(width,height)
# Out:
# 275 183

# %%
# Out:
#   File "<ipython-input-4-83a6c4f2a8ff>", line 1
#     int(floor(np.array(img))
#                             ^
# SyntaxError: unexpected EOF while parsing

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=1e838953-af84-41c0-a42f-feb686c0555a' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
